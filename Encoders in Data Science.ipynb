# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("/Users/nilesh/Encode_file.csv")

# %%
df1
# Out:
#    age  Gender     bmi Dibetes     region
# 0   19    male  27.900     yes  southwest
# 1   18  female  33.770      no  southeast
# 2   28    male  33.000      no  southeast
# 3   33    male  22.705     yes  northwest
# 4   32    male  28.880      no  northwest
# 5   31  female  25.740      no  southeast
# 6   46  female  33.440     yes  southeast
# 7   37  female  27.740      no  northwest
# 8   37    male  29.830      no  northeast
# 9   60  female  25.840      no   northest

# %%
df1.dtypes
# Out:
# age          int64
# Gender      object
# bmi        float64
# Dibetes     object
# region      object
# dtype: object

# %%
df1.region.unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast', 'northest'],
#       dtype=object)

# %%
df1[['Gender','Dibetes']] = df1[['Gender','Dibetes']].astype('category')

# %%
df1['region'] = df1['region'].astype('category')

# %%
#df['region'] = df['region'].cat.codes

# %%
df1.dtypes
# Out:
# age           int64
# Gender     category
# bmi         float64
# Dibetes    category
# region     category
# dtype: object

# %%
df1['Gender'] = df1['Gender'].cat.codes
df1['Dibetes'] = df1['Dibetes'].cat.codes

# %%
df1
# Out:
#    age  Gender     bmi  Dibetes     region
# 0   19       1  27.900        1  southwest
# 1   18       0  33.770        0  southeast
# 2   28       1  33.000        0  southeast
# 3   33       1  22.705        1  northwest
# 4   32       1  28.880        0  northwest
# 5   31       0  25.740        0  southeast
# 6   46       0  33.440        1  southeast
# 7   37       0  27.740        0  northwest
# 8   37       1  29.830        0  northeast
# 9   60       0  25.840        0   northest

# %%
df = pd.get_dummies(df1,columns=['region'])

# %%
df
# Out:
#    age  Gender     bmi  Dibetes  region_northeast  region_northest  \
# 0   19       1  27.900        1                 0                0
# 1   18       0  33.770        0                 0                0
# 2   28       1  33.000        0                 0                0
# 3   33       1  22.705        1                 0                0
# 4   32       1  28.880        0                 0                0
# 5   31       0  25.740        0                 0                0
# 6   46       0  33.440        1                 0                0
# 7   37       0  27.740        0                 0                0
# 8   37       1  29.830        0                 1                0
# 9   60       0  25.840        0                 0                1
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# ...

# %%
df1
# Out:
#    age  Gender     bmi  Dibetes     region
# 0   19       1  27.900        1  southwest
# 1   18       0  33.770        0  southeast
# 2   28       1  33.000        0  southeast
# 3   33       1  22.705        1  northwest
# 4   32       1  28.880        0  northwest
# 5   31       0  25.740        0  southeast
# 6   46       0  33.440        1  southeast
# 7   37       0  27.740        0  northwest
# 8   37       1  29.830        0  northeast
# 9   60       0  25.840        0   northest

# %%
# !pip install category_encoders
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# cufflinks 0.16 has requirement plotly<4.0.0a0,>=3.0.0, but you'll have plotly 4.8.2 which is incompatible.
# You are using pip version 10.0.1, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import category_encoders as ce

# %%
dfbin = df1.copy()

# %%
bincode = ce.BinaryEncoder(dfbin,cols=['region'])

# %%
df_bin = bincode.fit_transform(dfbin)

# %%
df_bin.head(10)
# Out:
#    age  Gender     bmi  Dibetes  region_0  region_1  region_2  region_3
# 0   19       1  27.900        1         0         1         0         1
# 1   18       0  33.770        0         0         1         0         0
# 2   28       1  33.000        0         0         1         0         0
# 3   33       1  22.705        1         0         0         1         1
# 4   32       1  28.880        0         0         0         1         1
# 5   31       0  25.740        0         0         1         0         0
# 6   46       0  33.440        1         0         1         0         0
# 7   37       0  27.740        0         0         0         1         1
# 8   37       1  29.830        0         0         0         0         1
# 9   60       0  25.840        0         0         0         1         0
